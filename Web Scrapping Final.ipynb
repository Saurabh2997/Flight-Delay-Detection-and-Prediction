# %%
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime

# %%
from bs4 import BeautifulSoup as BS
from selenium import webdriver
from functools import reduce
import pandas as pd
import time

# %%
df=pd.read_csv("WeatherDateLoc.csv")
df.head()
# Out:
#          Date Dest
# 0  03-01-2019  BWI
# 1  03-01-2019  LAS
# 2  03-01-2019  MCO
# 3  03-01-2019  PHX
# 4  03-01-2019  TPA

# %%
len(df.Dest.unique())
# Out:
# 259

# %%
df_1=df

# %%
df_1group=df_1.groupby('Dest')

# %%
df_1group.sum()
# Out:
#                                                    Date
# Dest
# ABE   01-01-201903-01-201906-01-201910-01-201913-01-...
# ABI   04-01-201917-01-201921-01-201923-01-201925-01-...
# ABQ   03-01-201903-01-201903-01-201903-01-201903-01-...
# ABY   02-01-201910-01-201913-01-201921-01-201931-01-...
# ACT   02-01-201908-01-201910-01-201911-01-201916-01-...
# ...                                                 ...
# WRG   05-01-201908-01-201909-01-201910-01-201910-01-...
# WYS   09-06-201913-06-201916-06-201917-06-201927-06-...
# XNA   01-01-201901-01-201902-01-201902-01-201902-01-...
# YAK   01-01-201903-01-201905-01-201906-01-201907-01-...
# YUM   02-01-201902-01-201904-01-201904-01-201904-01-...
#
# [259 rows x 1 columns]

# %%
df_1['Date'] = pd.to_datetime(df_1['Date'])
df_1['Date'].apply(lambda x: x.strftime('%Y-%m-%d')).astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-01-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df_output= pd.read_csv('web_scrape_PSC_trial.csv')

# %%
for k in df_1group:
    Test=df_1group.get_group(k[0])
    Test['Date'] = pd.to_datetime(Test['Date'])
    Test['Date'].apply(lambda x: x.strftime('%Y-%m')).astype(str)
    dates=[]
    loc=k[0]
    for i in Test['Date']:
        m=str(i)
        if m[:7] in dates:
            continue
        else:
            dates.append(m[:7])
            
        
    #print(dates,k[0])
    #WeatherFinder(dates,k[0],df_1)
    if (dates,loc) in Done_loc:
        continue
    else:
        print(Done_loc)
        page = f'https://www.wunderground.com/history/monthly/K{loc}/date/'
        df_output  = df_output.append(scraper(page,dates,loc))
    #df_output=scraper(page,dates,loc)
        Done_loc.append((dates,loc))
        print(df_output.shape)
        print('Finished',loc)

# %%
Done_loc=[(['2019-01', '2019-03', '2019-06', '2019-10', '2019-05', '2019-07', '2019-04', '2019-12', '2019-02', '2019-08', '2019-09', '2019-11'], 'ABE'), (['2019-04', '2019-01', '2019-06', '2019-02', '2019-08', '2019-12', '2019-11', '2019-10', '2019-05', '2019-07', '2019-09', '2019-03'], 'ABI'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'ABQ'), (['2019-02', '2019-10', '2019-01', '2019-04', '2019-08', '2019-03', '2019-07', '2019-06', '2019-11', '2019-05', '2019-12', '2019-09'], 'ABY'), (['2019-02', '2019-08', '2019-10', '2019-11', '2019-01', '2019-04', '2019-06', '2019-07', '2019-12', '2019-05', '2019-03', '2019-09'], 'ACT'), (['2019-01', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-02'], 'ACV'), (['2019-02', '2019-06', '2019-01', '2019-03', '2019-04'], 'ACY'), (['2019-01', '2019-03', '2019-10', '2019-06', '2019-04', '2019-11', '2019-05'], 'ADK'), (['2019-05', '2019-09', '2019-10', '2019-01', '2019-11', '2019-02', '2019-07', '2019-08', '2019-03', '2019-04'], 'ADQ'), (['2019-02', '2019-03', '2019-01', '2019-08', '2019-09', '2019-11', '2019-10', '2019-06', '2019-04', '2019-05', '2019-12', '2019-07'], 'AEX'), (['2019-04', '2019-08', '2019-01', '2019-03', '2019-06', '2019-10', '2019-11', '2019-07', '2019-02', '2019-12', '2019-09', '2019-05'], 'AGS'), (['2019-04', '2019-06', '2019-09', '2019-05'], 'AKN'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-01', '2019-02', '2019-11'], 'ALB'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-10', '2019-11', '2019-01', '2019-02', '2019-08', '2019-12', '2019-09'], 'AMA'), (['2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-12', '2019-01', '2019-03', '2019-09', '2019-11'], 'ANC'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'ASE'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-11', '2019-12', '2019-10'], 'ATL'), (['2019-01', '2019-02', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-03', '2019-04', '2019-05', '2019-06', '2019-12'], 'ATW'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'AUS'), (['2019-02', '2019-03', '2019-04', '2019-10', '2019-01', '2019-06', '2019-07', '2019-12', '2019-08', '2019-05', '2019-09', '2019-11'], 'AVL'), (['2019-01', '2019-02', '2019-07', '2019-10', '2019-08', '2019-11', '2019-06', '2019-03', '2019-04', '2019-05', '2019-12', '2019-09'], 'AVP'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-07', '2019-09', '2019-08', '2019-05', '2019-10', '2019-11', '2019-12', '2019-06'], 'AZO'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'BDL'), (['2019-05', '2019-09', '2019-10', '2019-01', '2019-04', '2019-08', '2019-11', '2019-02', '2019-03', '2019-06', '2019-07', '2019-12'], 'BET'), (['2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-12'], 'BFL'), (['2019-02', '2019-03', '2019-08', '2019-10', '2019-01', '2019-05', '2019-04', '2019-07', '2019-09', '2019-12', '2019-06', '2019-11'], 'BGR'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'BHM'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-12', '2019-11', '2019-08'], 'BIL'), (['2019-01', '2019-02', '2019-03', '2019-06', '2019-07', '2019-08', '2019-04', '2019-05', '2019-11', '2019-12', '2019-09', '2019-10'], 'BIS'), (['2019-05', '2019-01', '2019-02', '2019-03'], 'BLI'), (['2019-08', '2019-01', '2019-11', '2019-06', '2019-04', '2019-07', '2019-02', '2019-05', '2019-10', '2019-12', '2019-03', '2019-09'], 'BMI'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'BNA'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'BOI'), (['2019-05', '2019-01', '2019-06', '2019-04', '2019-07', '2019-11', '2019-10', '2019-03', '2019-08', '2019-09', '2019-02', '2019-12'], 'BOS'), (['2019-06', '2019-10', '2019-01', '2019-07', '2019-09', '2019-11', '2019-02', '2019-08', '2019-03', '2019-04', '2019-05'], 'BQK'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-11', '2019-03', '2019-06', '2019-08', '2019-10', '2019-07', '2019-09', '2019-12'], 'BQN'), (['2019-03', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-01', '2019-04', '2019-02', '2019-05', '2019-12', '2019-09'], 'BRW'), (['2019-05', '2019-06', '2019-07', '2019-01', '2019-03', '2019-08', '2019-02', '2019-04'], 'BTM'), (['2019-03', '2019-04', '2019-06', '2019-07', '2019-09', '2019-11', '2019-01', '2019-02', '2019-10', '2019-08', '2019-12', '2019-05'], 'BTR'), (['2019-01', '2019-03', '2019-02', '2019-05', '2019-06', '2019-07', '2019-10', '2019-12', '2019-04', '2019-11', '2019-08', '2019-09'], 'BTV'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'BUF'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'BUR'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'BWI'), (['2019-01', '2019-02', '2019-03', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-11', '2019-04', '2019-10', '2019-12'], 'BZN'), (['2019-01', '2019-02', '2019-03', '2019-08', '2019-10', '2019-04', '2019-06', '2019-09', '2019-07', '2019-11', '2019-12', '2019-05'], 'CAE'), (['2019-05', '2019-01', '2019-02', '2019-03', '2019-04', '2019-07', '2019-12', '2019-11', '2019-08', '2019-06', '2019-10', '2019-09'], 'CAK'), (['2019-08', '2019-09', '2019-11', '2019-01', '2019-03', '2019-06', '2019-07', '2019-02', '2019-04'], 'CDC'), (['2019-01', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-12', '2019-03', '2019-04', '2019-11', '2019-02'], 'CDV'), (['2019-03', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02', '2019-04'], 'CEC'), (['2019-10', '2019-01', '2019-04', '2019-03', '2019-02', '2019-05', '2019-08', '2019-11', '2019-07', '2019-09', '2019-06', '2019-12'], 'CHA'), (['2019-03', '2019-11', '2019-01', '2019-04', '2019-06', '2019-02', '2019-09', '2019-05', '2019-07', '2019-08', '2019-10', '2019-12'], 'CHO'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'CHS'), (['2019-02', '2019-07', '2019-08', '2019-09', '2019-01', '2019-03', '2019-10', '2019-11', '2019-05', '2019-06', '2019-04', '2019-12'], 'CID'), (['2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-01', '2019-03', '2019-10', '2019-02', '2019-12', '2019-11'], 'CLD'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'CLE'), (['2019-04', '2019-12', '2019-01', '2019-09', '2019-02', '2019-06', '2019-07', '2019-10', '2019-03', '2019-05', '2019-11', '2019-08'], 'CLL'), (['2019-07', '2019-10', '2019-01', '2019-08', '2019-11', '2019-03', '2019-02', '2019-05', '2019-06', '2019-04', '2019-09', '2019-12'], 'CLT'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'CMH'), (['2019-01', '2019-02', '2019-07', '2019-11', '2019-10', '2019-04', '2019-06', '2019-08', '2019-09', '2019-03', '2019-05', '2019-12'], 'CMI'), (['2019-06', '2019-11', '2019-01', '2019-02', '2019-04', '2019-07', '2019-05', '2019-03', '2019-10'], 'COD'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'COS'), (['2019-05', '2019-01', '2019-04', '2019-06', '2019-07', '2019-10', '2019-02', '2019-03', '2019-12', '2019-08', '2019-09'], 'CPR'), (['2019-05', '2019-06', '2019-08', '2019-01', '2019-02', '2019-03', '2019-10', '2019-12', '2019-04', '2019-07', '2019-11', '2019-09'], 'CRP'), (['2019-01', '2019-02', '2019-05', '2019-07', '2019-08', '2019-10', '2019-03', '2019-06', '2019-09', '2019-11', '2019-12', '2019-04'], 'CRW'), (['2019-04', '2019-01', '2019-03', '2019-06', '2019-02', '2019-08', '2019-11', '2019-05', '2019-07', '2019-10', '2019-09', '2019-12'], 'CSG'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-12', '2019-10', '2019-11'], 'CVG'), (['2019-01', '2019-02', '2019-05', '2019-03', '2019-11', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-04', '2019-12'], 'CWA'), (['2019-01', '2019-02', '2019-10', '2019-03', '2019-07', '2019-08', '2019-11', '2019-04', '2019-06', '2019-12', '2019-05', '2019-09'], 'DAB'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'DAL'), (['2019-01', '2019-05', '2019-06', '2019-07', '2019-02', '2019-11', '2019-12', '2019-08', '2019-04', '2019-03', '2019-10', '2019-09'], 'DAY'), (['2019-01', '2019-02', '2019-03', '2019-08', '2019-09', '2019-04', '2019-05', '2019-07', '2019-10', '2019-11', '2019-06', '2019-12'], 'DBQ'), (['2019-04', '2019-05', '2019-07', '2019-08', '2019-11', '2019-01', '2019-10', '2019-02', '2019-03', '2019-09', '2019-12', '2019-06'], 'DCA'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'DEN'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-11', '2019-12', '2019-10'], 'DFW'), (['2019-03', '2019-05', '2019-08', '2019-01', '2019-06', '2019-07', '2019-10', '2019-12', '2019-02', '2019-04', '2019-11', '2019-09'], 'DHN'), (['2019-04', '2019-06', '2019-09', '2019-05'], 'DLG'), (['2019-02', '2019-03', '2019-05', '2019-06', '2019-09', '2019-11', '2019-01', '2019-04', '2019-07', '2019-10', '2019-08', '2019-12'], 'DRO'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-06', '2019-07', '2019-05', '2019-08', '2019-12', '2019-09', '2019-10', '2019-11'], 'DSM'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-12', '2019-02'], 'DTW'), (['2019-05', '2019-01', '2019-04', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-02', '2019-03', '2019-06', '2019-11'], 'EGE'), (['2019-04', '2019-05', '2019-07', '2019-08', '2019-12', '2019-01', '2019-02', '2019-03', '2019-06'], 'EKO'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'ELP'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'EUG'), (['2019-01', '2019-03', '2019-05', '2019-06', '2019-07', '2019-02', '2019-09', '2019-10', '2019-11', '2019-12', '2019-08', '2019-04'], 'EVV'), (['2019-02', '2019-01', '2019-10', '2019-06', '2019-03', '2019-08', '2019-04', '2019-07', '2019-09', '2019-05', '2019-11', '2019-12'], 'EWN'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-11', '2019-08', '2019-12'], 'EWR'), (['2019-01', '2019-03', '2019-06', '2019-10', '2019-02', '2019-07', '2019-04', '2019-05', '2019-08', '2019-12', '2019-09', '2019-11'], 'EYW'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-01', '2019-02', '2019-11'], 'FAI'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'FAR'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'FAT'), (['2019-03', '2019-04', '2019-01', '2019-02', '2019-07', '2019-11', '2019-06', '2019-08', '2019-05', '2019-10', '2019-09', '2019-12'], 'FAY'), (['2019-01', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-02', '2019-03', '2019-12'], 'FCA'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-11', '2019-01', '2019-12', '2019-02', '2019-08'], 'FLL'), (['2019-06', '2019-10', '2019-01', '2019-03', '2019-08', '2019-02', '2019-07', '2019-12', '2019-05', '2019-11', '2019-09', '2019-04'], 'FNT'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-03', '2019-11', '2019-04'], 'FSD'), (['2019-03', '2019-09', '2019-01', '2019-02', '2019-04', '2019-06', '2019-12', '2019-08', '2019-10', '2019-11', '2019-05', '2019-07'], 'FSM'), (['2019-02', '2019-07', '2019-08', '2019-10', '2019-01', '2019-03', '2019-11', '2019-12', '2019-05', '2019-06', '2019-09', '2019-04'], 'FWA'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'GEG'), (['2019-01', '2019-10', '2019-04', '2019-02', '2019-12', '2019-05', '2019-08', '2019-11', '2019-06', '2019-07', '2019-03', '2019-09'], 'GGG'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-03', '2019-04', '2019-08', '2019-11', '2019-12'], 'GJT'), (['2019-02', '2019-03', '2019-01', '2019-08', '2019-07', '2019-05', '2019-11', '2019-10', '2019-06', '2019-09', '2019-04', '2019-12'], 'GNV'), (['2019-01', '2019-02', '2019-06', '2019-11', '2019-07', '2019-03', '2019-05', '2019-08', '2019-10', '2019-12', '2019-09', '2019-04'], 'GPT'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-08', '2019-10', '2019-12', '2019-07', '2019-11', '2019-09'], 'GRB'), (['2019-01', '2019-03', '2019-02', '2019-08', '2019-04', '2019-07', '2019-09', '2019-10', '2019-05', '2019-06', '2019-11', '2019-12'], 'GRK'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-12', '2019-11', '2019-03', '2019-10'], 'GRR'), (['2019-01', '2019-02', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-03', '2019-04', '2019-05', '2019-12', '2019-09'], 'GSO'), (['2019-01', '2019-08', '2019-11', '2019-03', '2019-04', '2019-09', '2019-02', '2019-05', '2019-06', '2019-10', '2019-12', '2019-07'], 'GSP'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-04', '2019-09', '2019-10', '2019-11', '2019-03', '2019-08', '2019-12'], 'GTF'), (['2019-03', '2019-06', '2019-07', '2019-10', '2019-01', '2019-05', '2019-02', '2019-08', '2019-04', '2019-09', '2019-11'], 'GTR'), (['2019-01', '2019-02', '2019-04', '2019-07', '2019-08', '2019-06', '2019-09', '2019-11', '2019-12', '2019-10', '2019-03', '2019-05'], 'GUC'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'HDN'), (['2019-05', '2019-06', '2019-09', '2019-12', '2019-01', '2019-04', '2019-02', '2019-03', '2019-07', '2019-08', '2019-10', '2019-11'], 'HLN'), (['2019-01', '2019-05', '2019-06', '2019-09', '2019-12', '2019-02', '2019-04', '2019-08', '2019-11', '2019-07', '2019-10', '2019-03'], 'HNL'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'HOU'), (['2019-08', '2019-01', '2019-06', '2019-02', '2019-03', '2019-04', '2019-11', '2019-07', '2019-09', '2019-10', '2019-05', '2019-12'], 'HPN'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-11', '2019-01', '2019-02', '2019-09', '2019-12', '2019-10'], 'HRL'), (['2019-01', '2019-07', '2019-11', '2019-04', '2019-08', '2019-03', '2019-10', '2019-02', '2019-06', '2019-05', '2019-09', '2019-12'], 'HSV'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-01', '2019-10', '2019-09', '2019-02', '2019-11', '2019-12'], 'IAD'), (['2019-01', '2019-02', '2019-03', '2019-05', '2019-07', '2019-06', '2019-08', '2019-09', '2019-12', '2019-04', '2019-11', '2019-10'], 'IAH'), (['2019-02', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-11', '2019-12', '2019-01', '2019-03', '2019-04', '2019-10'], 'ICT'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-03', '2019-04', '2019-11'], 'IDA'), (['2019-12', '2019-01', '2019-03', '2019-04', '2019-07', '2019-08', '2019-11', '2019-02', '2019-10', '2019-06', '2019-05', '2019-09'], 'ILM'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'IND'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'ISP'), (['2019-09', '2019-08', '2019-12', '2019-01', '2019-06', '2019-02', '2019-10', '2019-03', '2019-04', '2019-11', '2019-05', '2019-07'], 'ITO'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-12', '2019-04', '2019-11', '2019-03', '2019-08'], 'JAC'), (['2019-03', '2019-04', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-01', '2019-02', '2019-11', '2019-12', '2019-05'], 'JAN'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02', '2019-08'], 'JAX'), (['2019-05', '2019-01', '2019-04', '2019-10', '2019-02', '2019-08', '2019-11', '2019-12', '2019-06', '2019-09', '2019-07', '2019-03'], 'JFK'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-12', '2019-03', '2019-04', '2019-08', '2019-11'], 'JNU'), (['2019-02', '2019-04', '2019-05', '2019-06', '2019-12', '2019-01', '2019-08', '2019-10', '2019-11', '2019-03', '2019-09', '2019-07'], 'KOA'), (['2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-12', '2019-01', '2019-11'], 'KTN'), (['2019-01', '2019-02', '2019-05', '2019-07', '2019-12', '2019-03', '2019-08', '2019-09', '2019-11', '2019-04', '2019-10', '2019-06'], 'LAN'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'LAS'), (['2019-02', '2019-04', '2019-06', '2019-01', '2019-07', '2019-08', '2019-11', '2019-09', '2019-10', '2019-05', '2019-12', '2019-03'], 'LAW'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'LAX'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12', '2019-09'], 'LBB'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-03', '2019-04', '2019-12', '2019-09'], 'LEX'), (['2019-06', '2019-11', '2019-01', '2019-03', '2019-08', '2019-10', '2019-02', '2019-04', '2019-05', '2019-12', '2019-07', '2019-09'], 'LFT'), (['2019-03', '2019-04', '2019-09', '2019-01', '2019-11', '2019-12', '2019-02', '2019-05', '2019-07', '2019-08', '2019-10', '2019-06'], 'LGA'), (['2019-01', '2019-02', '2019-05', '2019-06', '2019-11', '2019-03', '2019-04', '2019-07', '2019-08', '2019-12', '2019-10', '2019-09'], 'LGB'), (['2019-04', '2019-01', '2019-03', '2019-05', '2019-06', '2019-02', '2019-12', '2019-08', '2019-11', '2019-10', '2019-07', '2019-09'], 'LIH'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'LIT'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-12', '2019-03', '2019-11', '2019-09'], 'LNK'), (['2019-03', '2019-06', '2019-08', '2019-10', '2019-01', '2019-05', '2019-02', '2019-04', '2019-12', '2019-07', '2019-11', '2019-09'], 'LRD'), (['2019-02', '2019-01', '2019-07', '2019-05', '2019-06', '2019-08', '2019-10', '2019-11', '2019-12', '2019-03', '2019-09', '2019-04'], 'LSE'), (['2019-01', '2019-03', '2019-04', '2019-02', '2019-10', '2019-05'], 'LWS'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-12', '2019-01', '2019-02', '2019-10', '2019-11'], 'MAF'), (['2019-02', '2019-03', '2019-05', '2019-08', '2019-01', '2019-07', '2019-10', '2019-11', '2019-09', '2019-04', '2019-06'], 'MBS'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'MCI'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'MCO'), (['2019-01', '2019-07', '2019-10', '2019-02', '2019-11', '2019-04', '2019-03', '2019-05', '2019-06', '2019-09', '2019-08', '2019-12'], 'MDT'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'MDW'), (['2019-03', '2019-10', '2019-11', '2019-01', '2019-08', '2019-04', '2019-02', '2019-06', '2019-12', '2019-05', '2019-07'], 'MEI'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'MEM'), (['2019-01', '2019-02', '2019-06', '2019-03', '2019-09', '2019-05', '2019-07', '2019-11', '2019-12', '2019-10', '2019-04', '2019-08'], 'MFE'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'MFR'), (['2019-02', '2019-04', '2019-01', '2019-09', '2019-03', '2019-06', '2019-07', '2019-10', '2019-05', '2019-08', '2019-11', '2019-12'], 'MGM'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-08', '2019-12'], 'MHT'), (['2019-02', '2019-03', '2019-05', '2019-09', '2019-10', '2019-11', '2019-01', '2019-04', '2019-06', '2019-07', '2019-12', '2019-08'], 'MIA'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'MKE'), (['2019-06', '2019-04', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-02', '2019-05'], 'MKG'), (['2019-01', '2019-03', '2019-06', '2019-02', '2019-04', '2019-05', '2019-08', '2019-11', '2019-07', '2019-10', '2019-12', '2019-09'], 'MLB'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-11', '2019-10', '2019-08', '2019-12'], 'MLI'), (['2019-02', '2019-01', '2019-03', '2019-06', '2019-04', '2019-12', '2019-05', '2019-08', '2019-10', '2019-11', '2019-07', '2019-09'], 'MLU'), (['2019-01', '2019-10', '2019-04', '2019-02', '2019-06', '2019-03', '2019-07', '2019-12', '2019-08', '2019-05', '2019-11', '2019-09'], 'MOB'), (['2019-01', '2019-02', '2019-05', '2019-12', '2019-07', '2019-10', '2019-11', '2019-08', '2019-03', '2019-04', '2019-09', '2019-06'], 'MQT'), (['2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01'], 'MRY'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-12', '2019-09'], 'MSN'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-09', '2019-12', '2019-03'], 'MSO'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'MSP'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'MSY'), (['2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-09', '2019-01', '2019-08', '2019-03', '2019-10', '2019-11', '2019-12'], 'MTJ'), (['2019-02', '2019-03', '2019-08', '2019-10', '2019-01', '2019-06', '2019-07', '2019-04', '2019-11', '2019-09', '2019-12', '2019-05'], 'MYR'), (['2019-02', '2019-03', '2019-10', '2019-01', '2019-07', '2019-11', '2019-04', '2019-09', '2019-05', '2019-06', '2019-08', '2019-12'], 'OAJ'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'OAK'), (['2019-02', '2019-04', '2019-05', '2019-06', '2019-01', '2019-07', '2019-08', '2019-10', '2019-03', '2019-11', '2019-12', '2019-09'], 'OGG'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'OKC'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02', '2019-09'], 'OMA'), (['2019-10', '2019-01', '2019-03', '2019-04', '2019-08', '2019-02', '2019-05', '2019-07', '2019-12', '2019-09', '2019-11'], 'OME'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02', '2019-09'], 'ONT'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12'], 'ORD'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02', '2019-09'], 'ORF'), (['2019-04', '2019-06', '2019-10', '2019-01', '2019-03', '2019-02', '2019-05', '2019-07', '2019-08', '2019-09', '2019-12', '2019-11'], 'OTZ'), (['2019-03', '2019-04', '2019-05', '2019-07', '2019-09', '2019-11', '2019-01', '2019-06', '2019-08', '2019-10', '2019-12', '2019-02'], 'PBI'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'PDX'), (['2019-03', '2019-06', '2019-07', '2019-01', '2019-11', '2019-02', '2019-08', '2019-10', '2019-12', '2019-05', '2019-04', '2019-09'], 'PHF'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'PHL'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'], 'PHX'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-10', '2019-11', '2019-03', '2019-09', '2019-12'], 'PIA'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-11', '2019-01', '2019-02', '2019-12'], 'PIH'), (['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-01', '2019-02', '2019-12'], 'PIT'), (['2019-01', '2019-05', '2019-02', '2019-03', '2019-04', '2019-06', '2019-12', '2019-08', '2019-10', '2019-09', '2019-07', '2019-11'], 'PNS'), (['2019-01', '2019-02', '2019-04', '2019-05', '2019-06', '2019-07', '2019-03', '2019-09', '2019-12', '2019-08', '2019-10', '2019-11'], 'PSC'), (['2019-01', '2019-02', '2019-03', '2019-04', '2019-06', '2019-11', '2019-07', '2019-10', '2019-12', '2019-08', '2019-09', '2019-05'], 'PSE'), (['2019-01', '2019-05', '2019-08', '2019-09', '2019-10', '2019-12', '2019-03', '2019-04', '2019-07', '2019-11', '2019-02', '2019-06'], 'PSG')]

# %%
Done_loc
# Out:
# [(['2019-01',
#    '2019-03',
#    '2019-06',
#    '2019-10',
#    '2019-05',
#    '2019-07',
#    '2019-04',
#    '2019-12',
#    '2019-02',
#    '2019-08',
#    '2019-09',
#    '2019-11'],
#   'ABE'),
#  (['2019-04',
#    '2019-01',
#    '2019-06',
#    '2019-02',
#    '2019-08',
#    '2019-12',
#    '2019-11',
#    '2019-10',
#    '2019-05',
#    '2019-07',
#    '2019-09',
#    '2019-03'],
#   'ABI'),
#  (['2019-03',
#    '2019-04',
#    '2019-05',
#    '2019-06',
#    '2019-07',
#    '2019-08',
#    '2019-09',
#    '2019-10',
#    '2019-11',
#    '2019-12',
#    '2019-01',
#    '2019-02'],
#   'ABQ'),
#  (['2019-02',
#    '2019-10',
#    '2019-01',
#    '2019-04',
#    '2019-08',
#    '2019-03',
#    '2019-07',
#    '2019-06',
#    '2019-11',
#    '2019-05',
#    '2019-12',
#    '2019-09'],
#   'ABY'),
#  (['2019-02',
#    '2019-08',
#    '2019-10',
#    '2019-11',
#    '2019-01',
#    '2019-04',
#    '2019-06',
#    '2019-07',
#    '2019-12',
#    '2019-05',
#    '2019-03',
# ...

# %%
#######################################################################
#def WeatherFinder(dates,loc,df_1):
## No Running

asdas
dates = ['2019-01','2019-06']#, '2019-06', '2019-10', '2019-05', '2019-07', '2019-04', '2019-12', '2019-02', '2019-08', '2019-09', '2019-11'] 
loc=['SFO','ADK','BWI']
df_output = pd.DataFrame()
for i in range(0,3):
    page = f'https://www.wunderground.com/history/monthly/K{loc[i]}/date/'
    df_output = df_output.append(scraper(page,dates,loc[i]))



#populate_org_data(df_1,df_output)
####################################################################################
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2668/816288667.py in <module>
#       3 ## No Running
#       4
# ----> 5 asdas
#       6 dates = ['2019-01','2019-06']#, '2019-06', '2019-10', '2019-05', '2019-07', '2019-04', '2019-12', '2019-02', '2019-08', '2019-09', '2019-11']
#       7 loc=['SFO','ADK','BWI']
#
# NameError: name 'asdas' is not defined

# %%
df_2group =df_1group

# %%
loc=k[0]
for k in df_2group:
    Test=df_2group.get_group(k[0])
    Test['Date'] = pd.to_datetime(Test['Date'])
    Test['Date'].apply(lambda x: x.strftime('%Y-%m')).astype(str)
    dates=[]
    
    for i in Test['Date']:
        m=str(i)
        if m[:7] in dates:
            continue
        else:
            dates.append(m[:7])
        
    print(dates,k[0])
   # WeatherFinder(dates,k[0],df_1)
    
   # page = f'https://www.wunderground.com/history/monthly/K{loc}/date/'
    #df_output = df_output.append(scraper(page,dates,loc))
    #df_output=scraper(page,dates,loc)
    #print(df_output.shape)
    #print('Finished',loc)
# Out:
# ['2019-01', '2019-03', '2019-06', '2019-10', '2019-05', '2019-07', '2019-04', '2019-12', '2019-02', '2019-08', '2019-09', '2019-11'] ABE
# ['2019-04', '2019-01', '2019-06', '2019-02', '2019-08', '2019-12', '2019-11', '2019-10', '2019-05', '2019-07', '2019-09', '2019-03'] ABI
# ['2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-01', '2019-02'] ABQ
# ['2019-02', '2019-10', '2019-01', '2019-04', '2019-08', '2019-03', '2019-07', '2019-06', '2019-11', '2019-05', '2019-12', '2019-09'] ABY
# ['2019-02', '2019-08', '2019-10', '2019-11', '2019-01', '2019-04', '2019-06', '2019-07', '2019-12', '2019-05', '2019-03', '2019-09'] ACT
# ['2019-01', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2019-02'] ACV
# ['2019-02', '2019-06', '2019-01', '2019-03', '2019-04'] ACY
# ['2019-01', '2019-03', '2019-10', '2019-06', '2019-04', '2019-11', '2019-05'] ADK
# ...

# %%
def render_page(url):
     
    driver = webdriver.Firefox(executable_path= r"C:/Users/AXP210092/Downloads/geckodriver-v0.32.0-win64/geckodriver.exe")
    #driver = webdriver.Chrome(executable_path="C:/Users/AXP210092/Downloads/chromedriver_win32/chromedriver")
    driver.set_script_timeout(10)
    driver.get(url)
    time.sleep(3)
    r = driver.page_source
    driver.quit()
    return r

# %%
def scraper(page, dates,loc):
    output = pd.DataFrame()

    for d in dates:

        url = str(str(page) + str(d))

        r = render_page(url)
        try:
            
            soup = BS(r, "html.parser")
            container = soup.find('lib-city-history-observation')
            check = container.find('tbody')
        except:
            return None
        

        data = []
        try:
            for c in check.find_all('tr', class_='ng-star-inserted'):
                    for i in c.find_all('td', class_='ng-star-inserted'):
                            trial = i.text
                            trial = trial.strip('  ')
                            data.append(trial)
        except:
            return None
                
        if round(len(data) / 17 - 1) == 31:
            Temperature = pd.DataFrame([data[32:128][x:x + 3] for x in range(0, len(data[32:128]), 3)][1:],
                                           columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[128:224][x:x + 3] for x in range(0, len(data[128:224]), 3)][1:],
                                         columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[224:320][x:x + 3] for x in range(0, len(data[224:320]), 3)][1:],
                                        columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[320:416][x:x + 3] for x in range(0, len(data[320:416]), 3)][1:],
                                    columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[416:512][x:x + 3] for x in range(0, len(data[416:512]), 3)][1:],
                                        columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:32][1:], columns=data[:1])
            Precipitation = pd.DataFrame(data[512:][1:], columns=['Precipitation'])
            
            print(str(str(d) + ' finished!'))
        elif round(len(data) / 17 - 1) == 28:
            Temperature = pd.DataFrame([data[29:116][x:x + 3] for x in range(0, len(data[29:116]), 3)][1:],
                                           columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[116:203][x:x + 3] for x in range(0, len(data[116:203]), 3)][1:],
                                         columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[203:290][x:x + 3] for x in range(0, len(data[203:290]), 3)][1:],
                                        columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[290:377][x:x + 3] for x in range(0, len(data[290:377]), 3)][1:],
                                    columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[377:464][x:x + 3] for x in range(0, len(data[377:463]), 3)][1:],
                                        columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:29][1:], columns=data[:1])
            Precipitation = pd.DataFrame(data[464:][1:], columns=['Precipitation'])
            print(str(str(d) + ' finished!'))
        elif round(len(data) / 17 - 1) == 29:
            Temperature = pd.DataFrame([data[30:120][x:x + 3] for x in range(0, len(data[30:120]), 3)][1:],
                                           columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[120:210][x:x + 3] for x in range(0, len(data[120:210]), 3)][1:],
                                         columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[210:300][x:x + 3] for x in range(0, len(data[210:300]), 3)][1:],
                                        columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[300:390][x:x + 3] for x in range(0, len(data[300:390]), 3)][1:],
                                    columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[390:480][x:x + 3] for x in range(0, len(data[390:480]), 3)][1:],
                                        columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:30][1:], columns=data[:1])
            Precipitation = pd.DataFrame(data[480:][1:], columns=['Precipitation'])
            print(str(str(d) + ' finished!'))
        elif round(len(data) / 17 - 1) == 30:
            Temperature = pd.DataFrame([data[31:124][x:x + 3] for x in range(0, len(data[31:124]), 3)][1:],
                                           columns=['Temp_max', 'Temp_avg', 'Temp_min'])
            Dew_Point = pd.DataFrame([data[124:217][x:x + 3] for x in range(0, len(data[124:217]), 3)][1:],
                                         columns=['Dew_max', 'Dew_avg', 'Dew_min'])
            Humidity = pd.DataFrame([data[217:310][x:x + 3] for x in range(0, len(data[217:310]), 3)][1:],
                                        columns=['Hum_max', 'Hum_avg', 'Hum_min'])
            Wind = pd.DataFrame([data[310:403][x:x + 3] for x in range(0, len(data[310:403]), 3)][1:],
                                    columns=['Wind_max', 'Wind_avg', 'Wind_min'])
            Pressure = pd.DataFrame([data[403:496][x:x + 3] for x in range(0, len(data[403:496]), 3)][1:],
                                        columns=['Pres_max', 'Pres_avg', 'Pres_min'])
            Date = pd.DataFrame(data[:31][1:], columns=data[:1])
            Precipitation = pd.DataFrame(data[496:][1:], columns=['Precipitation'])
            print(str(str(d) + ' finished!'))
        else:
            print(f'Data not in normal length',{d},{loc})

        dfs = [Date, Temperature, Dew_Point, Humidity, Wind, Pressure, Precipitation]

        df_final = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True), dfs)

        df_final['Date'] = str(d) + "-" + df_final.iloc[:, :1].astype(str)
        
        
        
        df_final['Dest'] = loc

        output = output.append(df_final)

    print('Scraper done!')

    output = output[['Temp_avg', 'Temp_min', 'Dew_max', 'Dew_avg', 'Dew_min', 'Hum_max',
                         'Hum_avg', 'Hum_min', 'Wind_max', 'Wind_avg', 'Wind_min', 'Pres_max',
                         'Pres_avg', 'Pres_min', 'Precipitation', 'Date', 'Dest']]
    output['Date'] = pd.to_datetime(output['Date'])
    
    output['Date'] = output.Date.apply(lambda x: x.strftime('%Y-%m-%d')).astype(str)
    return output

# %%
df_output['Dest'].unique()
# Out:
# array(['ABE', 'ABI', 'ABQ', 'ABY', 'ACT', 'ACV', 'ACY', 'AEX', 'AGS',
#        'ALB', 'AMA', 'ASE', 'ATL'], dtype=object)

# %%
df_output.to_csv('weather_scrap_data.csv')

# %%
Test['Date'] = pd.to_datetime(Test['Date'])
# Out:
# C:\Users\saura\AppData\Local\Temp/ipykernel_26608/2695310719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Test['Date'] = pd.to_datetime(Test['Date'])

# %%
len(dates)
# Out:
# 6927

# %%
df_output.to_csv('web_scrape_XNA_last.csv')

# %%
import numpy as np
np.sort(df.Dest.unique()[df_output.Dest.unique() not in df.Dest.unique()])
# Out:
# array([['ABE', 'ABI', 'ABQ', 'ABY', 'ACT', 'ACV', 'ACY', 'ADK', 'ADQ',
#         'AEX', 'AGS', 'AKN', 'ALB', 'AMA', 'ANC', 'ASE', 'ATL', 'ATW',
#         'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BET', 'BFL', 'BGR', 'BHM',
#         'BIL', 'BIS', 'BLI', 'BMI', 'BNA', 'BOI', 'BOS', 'BQK', 'BQN',
#         'BRW', 'BTM', 'BTR', 'BTV', 'BUF', 'BUR', 'BWI', 'BZN', 'CAE',
#         'CAK', 'CDC', 'CDV', 'CEC', 'CHA', 'CHO', 'CHS', 'CID', 'CLD',
#         'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COD', 'COS', 'CPR', 'CRP',
#         'CRW', 'CSG', 'CVG', 'CWA', 'DAB', 'DAL', 'DAY', 'DBQ', 'DCA',
#         'DEN', 'DFW', 'DHN', 'DLG', 'DRO', 'DSM', 'DTW', 'EGE', 'EKO',
#         'ELP', 'EUG', 'EVV', 'EWN', 'EWR', 'EYW', 'FAI', 'FAR', 'FAT',
#         'FAY', 'FCA', 'FLL', 'FNT', 'FSD', 'FSM', 'FWA', 'GEG', 'GGG',
#         'GJT', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR', 'GSO', 'GSP', 'GTF',
#         'GTR', 'GUC', 'HDN', 'HLN', 'HNL', 'HOU', 'HPN', 'HRL', 'HSV',
# ...

# %%
df_2=df_1
df_2['Date']=df_2.Date.astype('str')
df_output['Date']=df_output.Date.astype('str')

trial=pd.merge(df_2,df_output,on=['Dest','Date'],how='left')

# %%
trial.loc[trial['Dest'] == 'ABE'].head(50)
# Out:
#               Date Dest Temp_avg Temp_min Dew_max Dew_avg Dew_min Hum_max  \
# 17247   2019-01-01  ABE     47.6       41      48    39.5      29      93
# 18084   2019-03-01  ABE     30.2       26      28    22.1      14      82
# 19809   2019-06-01  ABE      NaN      NaN     NaN     NaN     NaN     NaN
# 21290   2019-10-01  ABE      NaN      NaN     NaN     NaN     NaN     NaN
# 21873   2019-01-13  ABE     28.7       23      21    13.0       6      75
# 22035   2019-01-14  ABE     25.5       17      15     9.7       7      65
# 22763   2019-01-17  ABE     28.5       22      21     8.8       3      72
# 24198   2019-01-21  ABE     11.3        6      -2    -6.9     -10      56
# 27290   2019-01-28  ABE     26.5       21      12     8.3       5      63
# 39314   2019-01-01  ABE     47.6       41      48    39.5      29      93
# 40245   2019-05-01  ABE      NaN      NaN     NaN     NaN     NaN     NaN
# 41155   2019-10-01  ABE      NaN      NaN     NaN     NaN     NaN     NaN
# ...
